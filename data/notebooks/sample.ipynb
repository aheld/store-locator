# %%
import pandas as pd
data = pd.read_excel('../farmersmarket_2024-3319163.xlsx')

# %%
data.head()
print(data.head())  # Show the first few rows
print(data.tail())  # Show the last few rows
print(data.shape)  # Get the number of rows and columns
print(data.info())  # Get information about data types
# Out:
#    listing_id          update_time                     listing_name  \
# 0      300002  2020-08-03 13:44:04     Colorado Farm and Art Market
# 1      300003  2020-08-03 09:33:29               Market in The Park
# 2      300004  2020-09-10 16:27:17    The Territory Farmers' Market
# 3      300005  2021-01-26 12:51:03  City of Plymouth Farmers Market
# 4      300006  2020-09-10 19:12:47           Durham Farmers' Market
#
#                                     location_address orgnization  \
# 0  7350 Pine Creek Road, Colorado Springs, Colora...         NaN
# 1                   300 Conti, Mobile, Alabama 36602         NaN
# 2       2000 Territory Drive, Galena, Illinois 61036         NaN
# 3     15500 County Road 6, Plymouth, Minnesota 55447         NaN
# 4    501 Foster Street, Durham, North Carolina 27701         NaN
#
#    orgnization_1  orgnization_2  orgnization_3  orgnization_4  \
# 0            NaN            NaN            NaN            NaN
# ...

# %%
print(data.orgnization[~data.orgnization.isnull()].head())
print(data.orgnization_1[~data.orgnization_1.isnull()].head())
# Out:
# 874    National Farmers Market Coalition;Tennessee Fa...
# 875    University of Wisconsin-Extention;Kenosha Comm...
# 876                    Blue Ridge Women in Agriculture ;
# 877                     Blue Ridge Women in Agriculture;
# 878      The Chamber for a Greater Chapel Hill-Carrboro;
# Name: orgnization, dtype: object
# 874    1.0
# 875    0.0
# 876    0.0
# 877    0.0
# 878    0.0
# Name: orgnization_1, dtype: float64
